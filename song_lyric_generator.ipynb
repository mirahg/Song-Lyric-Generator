# %%
# Imports

import io
import os
import sys
import csv
import string
import numpy as np
import pandas as pd
import tensorflow
from collections import Counter
from keras.models import Sequential
from sklearn.model_selection import train_test_split
from keras.callbacks import LambdaCallback, ModelCheckpoint, EarlyStopping
from keras.layers import Dense, Dropout, Activation, LSTM, Bidirectional, Embedding
from keras import Input, Model, backend, utils
from keras.layers import *
backend.clear_session()

# %%
# Put song data into dataframe

translator = str.maketrans('', '', string.punctuation)

df = pd.read_csv("lyrics.csv", sep="\t", engine="python", encoding="utf-8", error_bad_lines=False)
# Drops lyrics with NaN as their value
df.index.name = 'id'
df = df.dropna()

df.head()
# Out:
# Skipping line 3087: field larger than field limit (131072)
# Skipping line 3488: field larger than field limit (131072)
# Skipping line 4147: field larger than field limit (131072)
# Skipping line 5225: field larger than field limit (131072)
# Skipping line 5325: field larger than field limit (131072)
# Skipping line 5664: field larger than field limit (131072)
# Skipping line 5752: field larger than field limit (131072)
# Skipping line 5873: field larger than field limit (131072)
# Skipping line 5952: field larger than field limit (131072)
# Skipping line 6197: field larger than field limit (131072)
# Skipping line 6426: field larger than field limit (131072)
# Skipping line 6902: field larger than field limit (131072)
# Skipping line 7389: field larger than field limit (131072)
# Skipping line 7857: field larger than field limit (131072)
# Skipping line 8071: field larger than field limit (131072)
# Skipping line 8193: field larger than field limit (131072)
# Skipping line 8298: field larger than field limit (131072)
# Skipping line 8392: field larger than field limit (131072)
# Skipping line 8480: field larger than field limit (131072)
# Skipping line 8670: field larger than field limit (131072)
# Skipping line 8748: field larger than field limit (131072)
# Skipping line 8807: field larger than field limit (131072)
# Skipping line 8881: field larger than field limit (131072)
# Skipping line 8960: field larger than field limit (131072)
# Skipping line 8981: field larger than field limit (131072)
# Skipping line 9018: field larger than field limit (131072)
# Skipping line 9056: field larger than field limit (131072)
# Skipping line 9098: field larger than field limit (131072)
# Skipping line 9099: field larger than field limit (131072)
# Skipping line 9121: field larger than field limit (131072)
# Skipping line 9123: field larger than field limit (131072)
# Skipping line 9161: field larger than field limit (131072)
# Skipping line 9215: field larger than field limit (131072)
# Skipping line 9301: field larger than field limit (131072)
# Skipping line 9380: field larger than field limit (131072)
# Skipping line 9399: field larger than field limit (131072)
# Skipping line 9500: field larger than field limit (131072)
# Skipping line 9508: field larger than field limit (131072)
# Skipping line 9582: field larger than field limit (131072)
# Skipping line 9624: field larger than field limit (131072)
# Skipping line 9643: field larger than field limit (131072)
# Skipping line 9690: field larger than field limit (131072)
# Skipping line 9693: field larger than field limit (131072)
# Skipping line 9804: field larger than field limit (131072)
# Skipping line 9918: field larger than field limit (131072)
# Skipping line 9922: field larger than field limit (131072)
# Skipping line 9984: field larger than field limit (131072)
# Skipping line 10019: field larger than field limit (131072)
# Skipping line 10022: field larger than field limit (131072)
# Skipping line 10033: field larger than field limit (131072)
# Skipping line 10049: field larger than field limit (131072)
# Skipping line 10105: field larger than field limit (131072)
# Skipping line 10178: field larger than field limit (131072)
# Skipping line 10182: field larger than field limit (131072)
# Skipping line 10211: field larger than field limit (131072)
# Skipping line 10352: field larger than field limit (131072)
# Skipping line 10394: field larger than field limit (131072)
# Skipping line 10446: field larger than field limit (131072)
# Skipping line 10469: field larger than field limit (131072)
# Skipping line 10475: field larger than field limit (131072)
# Skipping line 10487: field larger than field limit (131072)
# Skipping line 10514: field larger than field limit (131072)
# Skipping line 10552: field larger than field limit (131072)
# Skipping line 10580: field larger than field limit (131072)
# Skipping line 10594: field larger than field limit (131072)
# Skipping line 10684: field larger than field limit (131072)
# Skipping line 10697: field larger than field limit (131072)
# Skipping line 10703: field larger than field limit (131072)
# Skipping line 10734: field larger than field limit (131072)
# Skipping line 10746: field larger than field limit (131072)
# Skipping line 10748: field larger than field limit (131072)
# Skipping line 10779: field larger than field limit (131072)
# Skipping line 10793: field larger than field limit (131072)
# Skipping line 10820: field larger than field limit (131072)
# Skipping line 10832: field larger than field limit (131072)
# Skipping line 10923: field larger than field limit (131072)
# Skipping line 10961: field larger than field limit (131072)
# Skipping line 10977: field larger than field limit (131072)
# Skipping line 11019: field larger than field limit (131072)
# Skipping line 11095: field larger than field limit (131072)
# Skipping line 11118: field larger than field limit (131072)
# Skipping line 11135: field larger than field limit (131072)
# Skipping line 11150: field larger than field limit (131072)
# Skipping line 11216: field larger than field limit (131072)
# Skipping line 11241: field larger than field limit (131072)
# Skipping line 11247: field larger than field limit (131072)
# Skipping line 11253: field larger than field limit (131072)
# Skipping line 11283: field larger than field limit (131072)
# Skipping line 11362: field larger than field limit (131072)
# Skipping line 11402: field larger than field limit (131072)
# Skipping line 11420: field larger than field limit (131072)
# Skipping line 11422: field larger than field limit (131072)
# Skipping line 11586: field larger than field limit (131072)
# Skipping line 11594: field larger than field limit (131072)
# Skipping line 11609: field larger than field limit (131072)
# Skipping line 11663: field larger than field limit (131072)
# Skipping line 11698: field larger than field limit (131072)
# Skipping line 11715: field larger than field limit (131072)
# Skipping line 11747: field larger than field limit (131072)
# Skipping line 11832: field larger than field limit (131072)
# Skipping line 11855: field larger than field limit (131072)
# Skipping line 11920: field larger than field limit (131072)
# Skipping line 11921: field larger than field limit (131072)
# Skipping line 11970: field larger than field limit (131072)
# Skipping line 11997: field larger than field limit (131072)
# Skipping line 12006: field larger than field limit (131072)
# Skipping line 12010: field larger than field limit (131072)
# Skipping line 12037: field larger than field limit (131072)
# Skipping line 12047: field larger than field limit (131072)
# Skipping line 12084: field larger than field limit (131072)
# Skipping line 12102: field larger than field limit (131072)
# Skipping line 12232: field larger than field limit (131072)
# Skipping line 12538: field larger than field limit (131072)
# Skipping line 12783: field larger than field limit (131072)
# Skipping line 12794: field larger than field limit (131072)
# Skipping line 12856: field larger than field limit (131072)
# Skipping line 12903: field larger than field limit (131072)
# Skipping line 13073: field larger than field limit (131072)
# Skipping line 13090: field larger than field limit (131072)
# Skipping line 13091: field larger than field limit (131072)
# Skipping line 13196: field larger than field limit (131072)
# Skipping line 13239: field larger than field limit (131072)
# Skipping line 13282: field larger than field limit (131072)
# Skipping line 13296: field larger than field limit (131072)
# Skipping line 13399: field larger than field limit (131072)
# Skipping line 13491: field larger than field limit (131072)
# Skipping line 13548: field larger than field limit (131072)
# Skipping line 13568: field larger than field limit (131072)
# Skipping line 13631: field larger than field limit (131072)
# Skipping line 13664: field larger than field limit (131072)
# Skipping line 13720: field larger than field limit (131072)
# Skipping line 13762: field larger than field limit (131072)
# Skipping line 13873: field larger than field limit (131072)
# Skipping line 13909: field larger than field limit (131072)
# Skipping line 13982: field larger than field limit (131072)
# Skipping line 14007: field larger than field limit (131072)
# Skipping line 14013: field larger than field limit (131072)
# Skipping line 14077: field larger than field limit (131072)
# Skipping line 14151: field larger than field limit (131072)
# Skipping line 14175: field larger than field limit (131072)
# Skipping line 14190: field larger than field limit (131072)
# Skipping line 14239: field larger than field limit (131072)
# Skipping line 14251: field larger than field limit (131072)
# Skipping line 14265: field larger than field limit (131072)
# Skipping line 14311: field larger than field limit (131072)
# Skipping line 14319: field larger than field limit (131072)
# Skipping line 14450: field larger than field limit (131072)
# Skipping line 14452: field larger than field limit (131072)
# Skipping line 14533: field larger than field limit (131072)
# Skipping line 14589: field larger than field limit (131072)
# Skipping line 14638: field larger than field limit (131072)
# Skipping line 14695: field larger than field limit (131072)
# Skipping line 14707: field larger than field limit (131072)
# Skipping line 14818: field larger than field limit (131072)
# Skipping line 14937: field larger than field limit (131072)
# Skipping line 14942: field larger than field limit (131072)
# Skipping line 14978: field larger than field limit (131072)
# Skipping line 15102: field larger than field limit (131072)
# Skipping line 15169: field larger than field limit (131072)
# Skipping line 15317: field larger than field limit (131072)
# Skipping line 15760: field larger than field limit (131072)
# Skipping line 15807: field larger than field limit (131072)
# Skipping line 15867: field larger than field limit (131072)
# Skipping line 15898: field larger than field limit (131072)
# Skipping line 15968: field larger than field limit (131072)
# Skipping line 16120: field larger than field limit (131072)
# Skipping line 16123: field larger than field limit (131072)
# Skipping line 16201: field larger than field limit (131072)
# Skipping line 16317: field larger than field limit (131072)
# Skipping line 16461: field larger than field limit (131072)
# Skipping line 16467: field larger than field limit (131072)
# Skipping line 16473: field larger than field limit (131072)
# Skipping line 16532: field larger than field limit (131072)
# Skipping line 16579: field larger than field limit (131072)
# Skipping line 16668: field larger than field limit (131072)
# Skipping line 16679: field larger than field limit (131072)
# Skipping line 16755: field larger than field limit (131072)
# Skipping line 16757: field larger than field limit (131072)
# Skipping line 16820: field larger than field limit (131072)
# Skipping line 16823: field larger than field limit (131072)
# Skipping line 16856: field larger than field limit (131072)
# Skipping line 16890: field larger than field limit (131072)
# Skipping line 16893: field larger than field limit (131072)
# Skipping line 17025: field larger than field limit (131072)
# Skipping line 17038: field larger than field limit (131072)
# Skipping line 17055: field larger than field limit (131072)
# Skipping line 17058: field larger than field limit (131072)
# Skipping line 17078: field larger than field limit (131072)
# Skipping line 17089: field larger than field limit (131072)
# Skipping line 17110: field larger than field limit (131072)
# Skipping line 17111: field larger than field limit (131072)
# Skipping line 17133: field larger than field limit (131072)
# Skipping line 17246: field larger than field limit (131072)
# Skipping line 17379: field larger than field limit (131072)
# Skipping line 17387: field larger than field limit (131072)
# Skipping line 17493: field larger than field limit (131072)
# Skipping line 17591: field larger than field limit (131072)
# Skipping line 17614: field larger than field limit (131072)
# Skipping line 17698: field larger than field limit (131072)
# Skipping line 17723: field larger than field limit (131072)
# Skipping line 17763: field larger than field limit (131072)
# Skipping line 17767: field larger than field limit (131072)
# Skipping line 17791: field larger than field limit (131072)
# Skipping line 17798: field larger than field limit (131072)
# Skipping line 17829: field larger than field limit (131072)
# Skipping line 17847: field larger than field limit (131072)
# Skipping line 17866: field larger than field limit (131072)
# Skipping line 17932: field larger than field limit (131072)
# Skipping line 17938: field larger than field limit (131072)
# Skipping line 17951: field larger than field limit (131072)
# Skipping line 18009: field larger than field limit (131072)
# Skipping line 18088: field larger than field limit (131072)
# Skipping line 18198: field larger than field limit (131072)
# Skipping line 18221: field larger than field limit (131072)
# Skipping line 18239: field larger than field limit (131072)
# Skipping line 18307: field larger than field limit (131072)
# Skipping line 18323: field larger than field limit (131072)
# Skipping line 18342: field larger than field limit (131072)
# Skipping line 18476: field larger than field limit (131072)
# Skipping line 18504: field larger than field limit (131072)
# Skipping line 18505: field larger than field limit (131072)
# Skipping line 18524: field larger than field limit (131072)
# Skipping line 18539: field larger than field limit (131072)
# Skipping line 18619: field larger than field limit (131072)
# Skipping line 18628: field larger than field limit (131072)
# Skipping line 18690: field larger than field limit (131072)
# Skipping line 18765: field larger than field limit (131072)
# Skipping line 18782: field larger than field limit (131072)
# Skipping line 18783: field larger than field limit (131072)
# Skipping line 19233: field larger than field limit (131072)
# Skipping line 19343: field larger than field limit (131072)
# Skipping line 19360: field larger than field limit (131072)
# Skipping line 19398: field larger than field limit (131072)
# Skipping line 19426: field larger than field limit (131072)
# Skipping line 19431: field larger than field limit (131072)
# Skipping line 19458: field larger than field limit (131072)
# Skipping line 19460: field larger than field limit (131072)
# Skipping line 19466: field larger than field limit (131072)
# Skipping line 19468: field larger than field limit (131072)
# Skipping line 19501: field larger than field limit (131072)
# Skipping line 19535: field larger than field limit (131072)
# Skipping line 19543: field larger than field limit (131072)
# Skipping line 19546: field larger than field limit (131072)
# Skipping line 19645: field larger than field limit (131072)
# Skipping line 19660: field larger than field limit (131072)
# Skipping line 19681: field larger than field limit (131072)
# Skipping line 19730: field larger than field limit (131072)
# Skipping line 19762: field larger than field limit (131072)
# Skipping line 19786: field larger than field limit (131072)
# Skipping line 19797: field larger than field limit (131072)
# Skipping line 19806: field larger than field limit (131072)
# Skipping line 19812: field larger than field limit (131072)
# Skipping line 19822: field larger than field limit (131072)
# Skipping line 19827: field larger than field limit (131072)
# Skipping line 19836: field larger than field limit (131072)
# Skipping line 19882: field larger than field limit (131072)
# Skipping line 19884: field larger than field limit (131072)
# Skipping line 19911: field larger than field limit (131072)
# Skipping line 20398: field larger than field limit (131072)
#                    song_id                                             lyrics
# id
# 0   3e9HZxeyfWwjeyPAMmWSSQ  ['[Verse 1]\nThought I\'d end up with Sean\nBu...
# 1   5p7ujcrUXASCNwRaWNHR1C  ["[Verse 1]\nFound you when your heart was bro...
# 2   2xLMifQCjDGFmkHkpNLD9h  ['[Part I]\n\n[Intro: Drake]\nAstro, yeah\nSun...
# 4   1rqqCSm0Qe4I9rUvWncaom  ["[Intro]\nHigh, high hopes\n\n[Chorus]\nHad t...
# 5   0bYg9bo50gSsH3LtXe2SQn  ["[Intro]\nI-I-I don't want a lot for Christma...

# %%
def split_text(x):

   text = x['lyrics']

   sections = text.split('\\n\\n')

   keys = {'Verse 1': np.nan,'Verse 2':np.nan,'Verse 3':np.nan,'Verse 4':np.nan, 'Chorus':np.nan}

   lyrics = str()

   single_text = []

   res = {}

   
   for s in sections:

       key = s[s.find('[') + 1:s.find(']')].strip()

       if ':' in key:

           key = key[:key.find(':')]
          

       if key in keys:
          single_text += [x.lower().replace('(','').replace(')','').translate(translator) for x in s[s.find(']')+1:].split('\\n') if len(x) > 1]

       res['single_text'] =  ' \n'.join(single_text)
   return pd.Series(res)


df = df.join( df.apply(split_text, axis=1), lsuffix="_Left", rsuffix="_Right")

df.head()
# Out:
#                    song_id                                             lyrics  \
# id
# 0   3e9HZxeyfWwjeyPAMmWSSQ  ['[Verse 1]\nThought I\'d end up with Sean\nBu...
# 1   5p7ujcrUXASCNwRaWNHR1C  ["[Verse 1]\nFound you when your heart was bro...
# 2   2xLMifQCjDGFmkHkpNLD9h  ['[Part I]\n\n[Intro: Drake]\nAstro, yeah\nSun...
# 4   1rqqCSm0Qe4I9rUvWncaom  ["[Intro]\nHigh, high hopes\n\n[Chorus]\nHad t...
# 5   0bYg9bo50gSsH3LtXe2SQn  ["[Intro]\nI-I-I don't want a lot for Christma...
#
#                                           single_text
# id
# 0   thank you next next \nthank you next next \nth...
# 1   tell me hows it feel sittin up there \nfeelin ...
# 2   woo made this here with all the ice on in the ...
# 4   had to have high high hopes for a living \nsho...
# 5   i dont want a lot for christmas \nthere is jus...

# %%
# Filtering our dataset for common vs. uncommon words
text_list = []
word_frequencies = Counter()
uncommon_words = set()
MIN_FREQUENCY = 7
MIN_SEQ = 5
BATCH_SIZE = 100


def extract_text(text):
   global text_list
   text_list += [w for w in text.split(' ') if w.strip() != '' or w == '\n']


df['single_text'].apply( extract_text )

print('Total words: ', len(text_list))


for w in text_list:

   word_frequencies[w] = word_frequencies.get(w, 0) + 1
  

uncommon_words = set([key for key in word_frequencies.keys() if word_frequencies[key] < MIN_FREQUENCY])

words = sorted(set([key for key in word_frequencies.keys() if word_frequencies[key] >= MIN_FREQUENCY]))


num_words = len(words)

word_indices = dict((w, i) for i, w in enumerate(words))

indices_word = dict((i, w) for i, w in enumerate(words))

print('Words with less than {} appearances: {}'.format( MIN_FREQUENCY, len(uncommon_words)))

print('Words with more than {} appearances: {}'.format( MIN_FREQUENCY, len(words)))


valid_seqs = []

end_seq_words = []

for i in range(len(text_list) - MIN_SEQ ):

   end_slice = i + MIN_SEQ + 1

   if len( set(text_list[i:end_slice]).intersection(uncommon_words) ) == 0:

       valid_seqs.append(text_list[i: i + MIN_SEQ])

       end_seq_words.append(text_list[i + MIN_SEQ])
      

print('Valid sequences of size {}: {}'.format(MIN_SEQ, len(valid_seqs)))


X_train, X_test, y_train, y_test = train_test_split(valid_seqs, end_seq_words, test_size=0.02, random_state=42)

print(X_train[2:5])
# Out:
# Total words:  2065446
# Words with less than 7 appearances: 32511
# Words with more than 7 appearances: 10579
# Valid sequences of size 5: 1768844
# [['ya', '\ni', 'can', 'tell', 'why'], ['\nyeah', 'the', 'sky', 'is', 'full'], ['\nhow', 'i', 'feel', '\nim', 'diggin']]

# %%
# Data generator for fit and evaluate

def generator(sentence_list, next_word_list, batch_size):

   index = 0

   while True:

       x = np.zeros((batch_size, MIN_SEQ), dtype=np.int32)

       y = np.zeros((batch_size), dtype=np.int32)

       for i in range(batch_size):

           for t, w in enumerate(sentence_list[index % len(sentence_list)]):

               x[i, t] = word_indices[w]

           y[i] = word_indices[next_word_list[index % len(sentence_list)]]

           index = index + 1

       yield x, y


# Functions from keras-team/keras/blob/master/examples/lstm_text_generation.py

def sample(preds, temperature=1.0):

   # helper function to sample an index from a probability array

   preds = np.asarray(preds).astype('float64')

   preds = np.log(preds) / temperature

   exp_preds = np.exp(preds)

   preds = exp_preds / np.sum(exp_preds)

   probas = np.random.multinomial(1, preds, 1)

   return np.argmax(probas)


def on_epoch_end(epoch, logs):
    # Function invoked at end of each epoch. Prints generated text.
    examples_file.write('\n----- Generating text after Epoch: %d\n' % epoch)
    sentences = []
    # Randomly pick a seed sequence
    with open("./lyric_prompts.csv") as file:
        reader = csv.reader(file)
        for row in reader:
            sentences.append(row[0].lower().replace(',',''))
    

    for sentence in sentences[1:5]:
        sentence = sentence.split()
        examples_file.write('----- Generating with seed:\n"' + ' '.join(sentence) + '"\n')
        examples_file.write(' '.join(sentence))

        for _ in range(50):
            x_pred = np.zeros((1, len(sentence)))
            for t, word in enumerate(sentence):
                x_pred[0, t] = word_indices[word]

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, 0.5)
            next_word = indices_word[next_index]

            sentence = sentence[1:]
            sentence.append(next_word)

            examples_file.write(" "+next_word)
        examples_file.write('\n')
    examples_file.write('='*80 + '\n')
    examples_file.flush()

# %%
def getModel():

   print('Build model...')

   model = Sequential()

   model.add(Embedding(input_dim=len(words), output_dim=1024))

   model.add(Bidirectional(LSTM(128)))

   model.add(Dense(len(words)))

   model.add(Activation('softmax'))

   return model

def getEncoder():
   # int sequences.
   enc_inputs = Input(shape=(20,), name='enc_inputs')

   
   # Embedding lookup and GRU
   embedding = Embedding(input_dim=100, output_dim=64)(enc_inputs)
   whole_sequence = GRU(4, return_sequences=True)(embedding)

   # Query-value attention of shape [batch_size, Tq, filters].
   query_value_attention_seq = Attention()([whole_sequence, whole_sequence])

   # build encoder model 
   encoder = Model(enc_inputs, query_value_attention_seq, name='encoder')

   return encoder

def getDecoder():
  # int sequences.
  dec_input = Input(shape=(20, 4), name='dec_inputs')

  # LSTM
  whole_sequence = LSTM(4, return_sequences=True)(dec_input)

  # Query-value attention of shape [batch_size, Tq, filters].
  query_value_attention_seq = AdditiveAttention()([whole_sequence, dec_input])

  # Reduce over the sequence axis to produce encodings of shape
  # [batch_size, filters].
  query_value_attention = GlobalAveragePooling1D()(query_value_attention_seq)

  # classification
  dec_output = Dense(1, activation='sigmoid')(query_value_attention)

  # build decoder model
  decoder = Model(dec_input, dec_output, name='decoder')
  return decoder

def getAutoEncoder():
  encoder = getEncoder()
  encoder_init = Input(shape=(20, ))
  encoder_output = encoder(encoder_init)
  print(encoder_output.shape)

  decoder = getDecoder()
  decoder_output = decoder(encoder_output)
  print(decoder_output.shape)

  autoencoder = Model(encoder_init, decoder_output)
  return autoencoder

# %%
# model = getAutoEncoder()
model = getModel()

model.compile(loss='sparse_categorical_crossentropy', optimizer="adam", metrics=['accuracy'])


file_path = "./checkpoints/LSTM_LYRICS-epoch{epoch:03d}-words%d-sequence%d-minfreq%d-loss{loss:.4f}-acc{accuracy:.4f}-val_loss{val_loss:.4f}-val_acc{val_accuracy:.4f}" % \
            (len(words), MIN_SEQ, MIN_FREQUENCY)


checkpoint = ModelCheckpoint(file_path, monitor='val_accuracy', save_best_only=True)

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

early_stopping = EarlyStopping(monitor='val_accuracy', patience=20)

callbacks_list = [checkpoint, print_callback, early_stopping]


examples_file = open('examples.txt', "w")

model.fit(generator(X_train, y_train, BATCH_SIZE),

                   steps_per_epoch=100, #int(len(valid_seqs)/BATCH_SIZE) + 1,

                   epochs=1,

                   callbacks=callbacks_list,

                   validation_data=generator(X_test, y_train, BATCH_SIZE),

                   validation_steps=int(len(y_train)/BATCH_SIZE) + 1)
# Out:
# Build model...
# C:\Users\alber\Anaconda3\lib\site-packages\tensorflow_core\python\framework\indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch 1/1
# 100/100 [==============================] - 957s 10s/step - loss: 7.5358 - accuracy: 0.0327 - val_loss: 7.2616 - val_accuracy: 0.0332
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-17-a89f5509965d> in <module>
#      30                    validation_data=generator(X_test, y_train, BATCH_SIZE),
#      31
# ---> 32                    validation_steps=int(len(y_train)/BATCH_SIZE) + 1)
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1145                 use_multiprocessing=use_multiprocessing,
#    1146                 shuffle=shuffle,
# -> 1147                 initial_epoch=initial_epoch)
#    1148
#    1149         # Case 2: Symbolic tensors or Numpy array-like.
#
# ~\Anaconda3\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1730             use_multiprocessing=use_multiprocessing,
#    1731             shuffle=shuffle,
# -> 1732             initial_epoch=initial_epoch)
#    1733
#    1734     @interfaces.legacy_generator_methods_support
#
# ~\Anaconda3\lib\site-packages\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     258                     break
#     259
# --> 260             callbacks.on_epoch_end(epoch, epoch_logs)
#     261             epoch += 1
#     262             if callbacks.model.stop_training:
#
# ~\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py in on_epoch_end(self, epoch, logs)
#     150         logs = logs or {}
#     151         for callback in self.callbacks:
# --> 152             callback.on_epoch_end(epoch, logs)
#     153
#     154     def on_train_batch_begin(self, batch, logs=None):
#
# ~\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py in on_epoch_end(self, epoch, logs)
#     717                             self.model.save_weights(filepath, overwrite=True)
#     718                         else:
# --> 719                             self.model.save(filepath, overwrite=True)
#     720                     else:
#     721                         if self.verbose > 0:
#
# ~\Anaconda3\lib\site-packages\keras\engine\network.py in save(self, filepath, overwrite, include_optimizer)
#    1150             raise NotImplementedError
#    1151         from ..models import save_model
# -> 1152         save_model(self, filepath, overwrite, include_optimizer)
#    1153
#    1154     @saving.allow_write_to_gcs
#
# ~\Anaconda3\lib\site-packages\keras\engine\saving.py in save_wrapper(obj, filepath, overwrite, *args, **kwargs)
#     447                 os.remove(tmp_filepath)
#     448         else:
# --> 449             save_function(obj, filepath, overwrite, *args, **kwargs)
#     450
#     451     return save_wrapper
#
# ~\Anaconda3\lib\site-packages\keras\engine\saving.py in save_model(model, filepath, overwrite, include_optimizer)
#     538             if not proceed:
#     539                 return
# --> 540         with H5Dict(filepath, mode='w') as h5dict:
#     541             _serialize_model(model, h5dict, include_optimizer)
#     542     elif hasattr(filepath, 'write') and callable(filepath.write):
#
# ~\Anaconda3\lib\site-packages\keras\utils\io_utils.py in __init__(self, path, mode)
#     189             self._is_file = False
#     190         elif isinstance(path, six.string_types) or _is_path_instance(path):
# --> 191             self.data = h5py.File(path, mode=mode)
#     192             self._is_file = True
#     193         elif isinstance(path, dict):
#
# ~\Anaconda3\lib\site-packages\h5py\_hl\files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     392                 fid = make_fid(name, mode, userblock_size,
#     393                                fapl, fcpl=make_fcpl(track_order=track_order),
# --> 394                                swmr=swmr)
#     395
#     396             if swmr_support:
#
# ~\Anaconda3\lib\site-packages\h5py\_hl\files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     174         fid = h5f.create(name, h5f.ACC_EXCL, fapl=fapl, fcpl=fcpl)
#     175     elif mode == 'w':
# --> 176         fid = h5f.create(name, h5f.ACC_TRUNC, fapl=fapl, fcpl=fcpl)
#     177     elif mode == 'a':
#     178         # Open in append mode (read/write).
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\h5f.pyx in h5py.h5f.create()
#
# OSError: Unable to create file (unable to open file: name = './checkpoints/LSTM_LYRICS-epoch001-words10579-sequence5-minfreq7-loss7.5358-acc0.0327-val_loss7.2616-val_acc0.0332', errno = 2, error message = 'No such file or directory', flags = 13, o_flags = 302)
